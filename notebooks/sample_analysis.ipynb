# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.DataFrame({
    "Asteroids": [5, 8, 12, 20],
    "RiskScore": [10, 25, 40, 80]
})

print(data)

plt.plot(data["Asteroids"], data["RiskScore"])
plt.title("Sample Risk Trend")
plt.show()
# Out:
#    Asteroids  RiskScore
# 0          5         10
# 1          8         25
# 2         12         40
# 3         20         80
